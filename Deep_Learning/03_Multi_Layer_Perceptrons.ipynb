# %% [markdown]
# <a href="https://colab.research.google.com/github/2018007956/HYU/blob/main/Deep_Learning/03_Multi_Layer_Perceptrons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Linear Regression

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# ## 신경망모델 학습 프로세스
# ### 1. Data processing

# %%
x_train = torch.FloatTensor([[1],[2],[3]])
y_train = torch.FloatTensor([[1],[2],[3]])

# %% [markdown]
# ### 2. Model design
# #### - layer 종류, 개수 및 뉴런 개수 설정
# #### - 각 layer 마다의 activation function 설정

# %%
W = torch.rand(1, requires_grad=True) # set model
b = torch.rand(1, requires_grad=True)

# %% [markdown]
# ### 3. Loss function 설정

# %%
def criterion(y_hat, y): # set loss function
  return torch.mean((y_hat-y)**2)

# %% [markdown]
# ### 4. Optimizer 설정

# %%
# optimizer = optim.SGD([W,b],lr=0.01) # set optimizer

# %%
class LinearRegression(nn.Module):
  def __init__(self, x_in, x_out):
    super(LinearRegression, self).__init__()
    self.linear = nn.Linear(x_in, x_out)
  def forward(self, x):
    return self.linear(x)

model = LinearRegression(1, 1)
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %% [markdown]
# ### 5. 학습

# %%
epochs = 30
for epoch in range(epochs):
  hypothesis = x_train * W + b # forward propagation
  cost = criterion(hypothesis, y_train) # get cost

  optimizer.zero_grad() # Gradient 0으로 Reset
  cost.backward() # backward propagation
  optimizer.step() # update parameters

  # print('Epoch {:4d}/{} Cost: {:.6f} W: {:.3f}, b: {:.3f}'.format(epoch, epochs, cost.item(), W.item(), b.item()) )
  print('Epoch {:4d}/{} Cost: {:.6f} W: {:.3f}, b: {:.3f}'.format(epoch, epochs, cost.item(), model.linear.weight.item(), model.linear.bias.item()) )
# Out:
# Epoch    0/30 Cost: 2.245345 W: 0.273, b: 0.258
# Epoch    1/30 Cost: 1.781744 W: 0.331, b: 0.282
# Epoch    2/30 Cost: 1.415259 W: 0.382, b: 0.303
# Epoch    3/30 Cost: 1.125539 W: 0.427, b: 0.322
# Epoch    4/30 Cost: 0.896498 W: 0.468, b: 0.338
# Epoch    5/30 Cost: 0.715421 W: 0.504, b: 0.353
# Epoch    6/30 Cost: 0.572256 W: 0.536, b: 0.366
# Epoch    7/30 Cost: 0.459060 W: 0.565, b: 0.377
# Epoch    8/30 Cost: 0.369552 W: 0.590, b: 0.387
# Epoch    9/30 Cost: 0.298769 W: 0.613, b: 0.395
# Epoch   10/30 Cost: 0.242786 W: 0.634, b: 0.403
# Epoch   11/30 Cost: 0.198503 W: 0.652, b: 0.410
# Epoch   12/30 Cost: 0.163468 W: 0.668, b: 0.415
# Epoch   13/30 Cost: 0.135744 W: 0.682, b: 0.420
# Epoch   14/30 Cost: 0.113797 W: 0.695, b: 0.425
# Epoch   15/30 Cost: 0.096419 W: 0.706, b: 0.428
# Epoch   16/30 Cost: 0.082651 W: 0.717, b: 0.431
# Epoch   17/30 Cost: 0.071737 W: 0.726, b: 0.434
# Epoch   18/30 Cost: 0.063080 W: 0.734, b: 0.436
# Epoch   19/30 Cost: 0.056206 W: 0.741, b: 0.438
# Epoch   20/30 Cost: 0.050742 W: 0.748, b: 0.440
# Epoch   21/30 Cost: 0.046393 W: 0.754, b: 0.441
# Epoch   22/30 Cost: 0.042925 W: 0.759, b: 0.442
# Epoch   23/30 Cost: 0.040153 W: 0.764, b: 0.443
# Epoch   24/30 Cost: 0.037933 W: 0.768, b: 0.444
# Epoch   25/30 Cost: 0.036148 W: 0.772, b: 0.444
# Epoch   26/30 Cost: 0.034707 W: 0.776, b: 0.444
# Epoch   27/30 Cost: 0.033539 W: 0.779, b: 0.444
# Epoch   28/30 Cost: 0.032587 W: 0.782, b: 0.444
# Epoch   29/30 Cost: 0.031805 W: 0.784, b: 0.444

# %% [markdown]
# #2. Logistic Regression

# %%
import torch
import torch.nn as nn
import torch.optim as optim

x_train = torch.FloatTensor([[0,0],[0,1],[1,0],[1,1]])
y_train = torch.FloatTensor([[0],[0],[0],[1]])

class LinearRegression(nn.Module):
  def __init__(self, x_in, x_out):
    super(LinearRegression, self).__init__()
    self.linear = nn.Linear(x_in, x_out)
    self.activation = nn.Sigmoid()
  def forward(self, x):
    z = self.linear(x)
    a = self.activation(z)
    return a

model = LinearRegression(2, 1).train()
optimizer = optim.SGD(model.parameters(), lr=0.01)
criterion = nn.BCELoss()

# %%
epochs = 8000
for epoch in range(epochs):
  model.train()
  hypothesis = model(x_train) # forward propagation
  cost = criterion(hypothesis+1e-8, y_train) # get cost
  optimizer.zero_grad() # Gradient 0으로 Reset
  cost.backward() # backward propagation
  optimizer.step() # update parameters

  if epoch != 0 and epoch % 100 == 0:
    model.eval()
    with torch.no_grad():
      predicts = (model(x_train))
      print('predict with model : {}'.format(predicts))
      print('real value y : {}'.format(y_train))
# Out:
# predict with model : tensor([[0.4132],
#         [0.3872],
#         [0.4665],
#         [0.4396]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.3748],
#         [0.3611],
#         [0.4341],
#         [0.4197]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.3433],
#         [0.3432],
#         [0.4107],
#         [0.4106]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.3169],
#         [0.3307],
#         [0.3934],
#         [0.4086]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.2943],
#         [0.3218],
#         [0.3802],
#         [0.4110]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.2744],
#         [0.3151],
#         [0.3697],
#         [0.4164]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.2567],
#         [0.3100],
#         [0.3611],
#         [0.4237]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.2407],
#         [0.3059],
#         [0.3538],
#         [0.4321]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.2262],
#         [0.3024],
#         [0.3474],
#         [0.4412]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.2129],
#         [0.2994],
#         [0.3417],
#         [0.4506]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.2006],
#         [0.2967],
#         [0.3365],
#         [0.4601]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1893],
#         [0.2941],
#         [0.3316],
#         [0.4695]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1788],
#         [0.2916],
#         [0.3270],
#         [0.4788]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1690],
#         [0.2893],
#         [0.3225],
#         [0.4879]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1599],
#         [0.2869],
#         [0.3183],
#         [0.4968]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1514],
#         [0.2846],
#         [0.3142],
#         [0.5053]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1434],
#         [0.2823],
#         [0.3102],
#         [0.5136]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1360],
#         [0.2800],
#         [0.3063],
#         [0.5217]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1291],
#         [0.2777],
#         [0.3025],
#         [0.5294]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1226],
#         [0.2754],
#         [0.2989],
#         [0.5369]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1165],
#         [0.2731],
#         [0.2953],
#         [0.5441]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1108],
#         [0.2708],
#         [0.2917],
#         [0.5511]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1054],
#         [0.2685],
#         [0.2883],
#         [0.5578]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1004],
#         [0.2662],
#         [0.2850],
#         [0.5643]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0957],
#         [0.2640],
#         [0.2817],
#         [0.5706]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0912],
#         [0.2617],
#         [0.2784],
#         [0.5767]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0870],
#         [0.2595],
#         [0.2753],
#         [0.5826]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0831],
#         [0.2572],
#         [0.2722],
#         [0.5884]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0794],
#         [0.2550],
#         [0.2692],
#         [0.5939]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0759],
#         [0.2528],
#         [0.2663],
#         [0.5993]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0726],
#         [0.2507],
#         [0.2634],
#         [0.6045]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0694],
#         [0.2485],
#         [0.2605],
#         [0.6095]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0665],
#         [0.2464],
#         [0.2578],
#         [0.6145]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0637],
#         [0.2442],
#         [0.2551],
#         [0.6192]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0611],
#         [0.2421],
#         [0.2524],
#         [0.6239]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0585],
#         [0.2401],
#         [0.2498],
#         [0.6284]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0562],
#         [0.2380],
#         [0.2472],
#         [0.6328]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0539],
#         [0.2360],
#         [0.2447],
#         [0.6371]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0518],
#         [0.2340],
#         [0.2423],
#         [0.6413]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0498],
#         [0.2320],
#         [0.2399],
#         [0.6454]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0478],
#         [0.2300],
#         [0.2375],
#         [0.6494]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0460],
#         [0.2281],
#         [0.2352],
#         [0.6532]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0443],
#         [0.2261],
#         [0.2329],
#         [0.6570]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0426],
#         [0.2243],
#         [0.2307],
#         [0.6607]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0410],
#         [0.2224],
#         [0.2285],
#         [0.6643]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0395],
#         [0.2205],
#         [0.2264],
#         [0.6679]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0381],
#         [0.2187],
#         [0.2243],
#         [0.6713]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0367],
#         [0.2169],
#         [0.2222],
#         [0.6747]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0354],
#         [0.2151],
#         [0.2202],
#         [0.6780]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0342],
#         [0.2134],
#         [0.2182],
#         [0.6813]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0330],
#         [0.2116],
#         [0.2162],
#         [0.6844]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0319],
#         [0.2099],
#         [0.2143],
#         [0.6875]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0308],
#         [0.2082],
#         [0.2124],
#         [0.6906]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0298],
#         [0.2066],
#         [0.2105],
#         [0.6935]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0288],
#         [0.2049],
#         [0.2087],
#         [0.6965]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0278],
#         [0.2033],
#         [0.2069],
#         [0.6993]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0269],
#         [0.2017],
#         [0.2051],
#         [0.7021]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0260],
#         [0.2001],
#         [0.2034],
#         [0.7049]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0252],
#         [0.1985],
#         [0.2017],
#         [0.7076]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0244],
#         [0.1970],
#         [0.2000],
#         [0.7102]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0236],
#         [0.1955],
#         [0.1983],
#         [0.7128]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0229],
#         [0.1940],
#         [0.1967],
#         [0.7154]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0222],
#         [0.1925],
#         [0.1951],
#         [0.7179]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0215],
#         [0.1910],
#         [0.1935],
#         [0.7203]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0209],
#         [0.1896],
#         [0.1919],
#         [0.7228]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0202],
#         [0.1881],
#         [0.1904],
#         [0.7251]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0196],
#         [0.1867],
#         [0.1889],
#         [0.7275]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0191],
#         [0.1853],
#         [0.1874],
#         [0.7298]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0185],
#         [0.1839],
#         [0.1859],
#         [0.7320]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0180],
#         [0.1826],
#         [0.1845],
#         [0.7342]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0174],
#         [0.1813],
#         [0.1831],
#         [0.7364]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0170],
#         [0.1799],
#         [0.1817],
#         [0.7386]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0165],
#         [0.1786],
#         [0.1803],
#         [0.7407]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0160],
#         [0.1773],
#         [0.1789],
#         [0.7428]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0156],
#         [0.1761],
#         [0.1776],
#         [0.7448]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0151],
#         [0.1748],
#         [0.1763],
#         [0.7468]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0147],
#         [0.1736],
#         [0.1750],
#         [0.7488]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0143],
#         [0.1723],
#         [0.1737],
#         [0.7508]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0139],
#         [0.1711],
#         [0.1724],
#         [0.7527]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])

# %% [markdown]
# #3. Multi-Layer Perceptron

# %%
import torch
import torch.nn as nn
import torch.optim as optim

x_train = torch.FloatTensor([[0,0],[0,1],[1,0],[1,1]])
y_train = torch.FloatTensor([[0],[0],[0],[1]])

class MultiLayerPerceptron(nn.Module):
  def __init__(self):
    super(MultiLayerPerceptron, self).__init__()
    self.linear = nn.Linear(2, 3)
    self.activation = nn.Sigmoid()
    self.linear2 = nn.Linear(3, 1)

  def forward(self, x):
    z1 = self.linear(x)
    a1 = self.activation(z1)

    z2 = self.linear2(a1)
    a2 = self.activation(z2)
    return a2

model = MultiLayerPerceptron().train()
optimizer = optim.SGD(model.parameters(), lr=0.01)
criterion = nn.BCELoss()

# %%
epochs = 8000
for epoch in range(epochs):
  model.train()
  hypothesis = model(x_train) # forward propagation
  cost = criterion(hypothesis+1e-8, y_train) # get cost
  optimizer.zero_grad() # Gradient 0으로 Reset
  cost.backward() # backward propagation
  optimizer.step() # update parameters

  if epoch != 0 and epoch % 100 == 0:
    model.eval()
    with torch.no_grad():
      predicts = (model(x_train))
      print('predict with model : {}'.format(predicts))
      print('real value y : {}'.format(y_train))
# Out:
# predict with model : tensor([[0.3949],
#         [0.4217],
#         [0.4106],
#         [0.4363]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.3369],
#         [0.3637],
#         [0.3543],
#         [0.3803]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.2999],
#         [0.3271],
#         [0.3186],
#         [0.3452]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.2754],
#         [0.3036],
#         [0.2954],
#         [0.3231]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.2584],
#         [0.2880],
#         [0.2799],
#         [0.3091]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.2463],
#         [0.2776],
#         [0.2692],
#         [0.3003]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.2372],
#         [0.2706],
#         [0.2618],
#         [0.2950]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.2301],
#         [0.2657],
#         [0.2564],
#         [0.2921]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.2242],
#         [0.2624],
#         [0.2525],
#         [0.2908]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.2193],
#         [0.2601],
#         [0.2496],
#         [0.2906]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.2149],
#         [0.2585],
#         [0.2474],
#         [0.2913]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.2109],
#         [0.2574],
#         [0.2456],
#         [0.2926]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.2071],
#         [0.2566],
#         [0.2441],
#         [0.2943]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.2035],
#         [0.2561],
#         [0.2429],
#         [0.2965]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1999],
#         [0.2557],
#         [0.2418],
#         [0.2989]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1964],
#         [0.2555],
#         [0.2409],
#         [0.3016]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1929],
#         [0.2554],
#         [0.2400],
#         [0.3045]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1893],
#         [0.2553],
#         [0.2391],
#         [0.3075]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1857],
#         [0.2553],
#         [0.2383],
#         [0.3108]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1821],
#         [0.2552],
#         [0.2376],
#         [0.3142]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1784],
#         [0.2552],
#         [0.2368],
#         [0.3177]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1747],
#         [0.2552],
#         [0.2360],
#         [0.3214]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1709],
#         [0.2552],
#         [0.2352],
#         [0.3253]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1671],
#         [0.2551],
#         [0.2345],
#         [0.3292]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1633],
#         [0.2551],
#         [0.2337],
#         [0.3333]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1594],
#         [0.2550],
#         [0.2329],
#         [0.3376]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1555],
#         [0.2548],
#         [0.2320],
#         [0.3419]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1515],
#         [0.2547],
#         [0.2312],
#         [0.3464]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1475],
#         [0.2545],
#         [0.2303],
#         [0.3510]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1436],
#         [0.2542],
#         [0.2294],
#         [0.3557]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1396],
#         [0.2539],
#         [0.2284],
#         [0.3605]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1356],
#         [0.2535],
#         [0.2275],
#         [0.3654]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1316],
#         [0.2531],
#         [0.2265],
#         [0.3705]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1276],
#         [0.2526],
#         [0.2254],
#         [0.3756]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1237],
#         [0.2520],
#         [0.2244],
#         [0.3808]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1197],
#         [0.2514],
#         [0.2232],
#         [0.3861]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1159],
#         [0.2506],
#         [0.2221],
#         [0.3915]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1120],
#         [0.2499],
#         [0.2209],
#         [0.3969]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1082],
#         [0.2490],
#         [0.2197],
#         [0.4024]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1045],
#         [0.2480],
#         [0.2184],
#         [0.4080]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.1008],
#         [0.2470],
#         [0.2171],
#         [0.4136]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0972],
#         [0.2459],
#         [0.2157],
#         [0.4193]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0936],
#         [0.2447],
#         [0.2143],
#         [0.4251]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0901],
#         [0.2434],
#         [0.2129],
#         [0.4309]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0867],
#         [0.2420],
#         [0.2114],
#         [0.4367]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0834],
#         [0.2406],
#         [0.2099],
#         [0.4425]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0802],
#         [0.2390],
#         [0.2084],
#         [0.4484]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0771],
#         [0.2374],
#         [0.2068],
#         [0.4543]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0740],
#         [0.2358],
#         [0.2052],
#         [0.4602]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0710],
#         [0.2340],
#         [0.2035],
#         [0.4662]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0682],
#         [0.2322],
#         [0.2019],
#         [0.4721]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0654],
#         [0.2303],
#         [0.2002],
#         [0.4781]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0627],
#         [0.2284],
#         [0.1984],
#         [0.4841]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0601],
#         [0.2264],
#         [0.1967],
#         [0.4901]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0576],
#         [0.2243],
#         [0.1949],
#         [0.4961]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0552],
#         [0.2222],
#         [0.1931],
#         [0.5021]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0529],
#         [0.2200],
#         [0.1913],
#         [0.5080]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0506],
#         [0.2178],
#         [0.1894],
#         [0.5140]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0485],
#         [0.2156],
#         [0.1876],
#         [0.5200]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0464],
#         [0.2133],
#         [0.1857],
#         [0.5259]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0444],
#         [0.2110],
#         [0.1838],
#         [0.5318]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0425],
#         [0.2086],
#         [0.1819],
#         [0.5378]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0407],
#         [0.2063],
#         [0.1799],
#         [0.5436]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0389],
#         [0.2039],
#         [0.1780],
#         [0.5495]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0373],
#         [0.2015],
#         [0.1761],
#         [0.5554]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0357],
#         [0.1990],
#         [0.1741],
#         [0.5612]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0341],
#         [0.1966],
#         [0.1721],
#         [0.5670]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0327],
#         [0.1942],
#         [0.1702],
#         [0.5727]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0312],
#         [0.1917],
#         [0.1682],
#         [0.5784]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0299],
#         [0.1893],
#         [0.1662],
#         [0.5841]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0286],
#         [0.1868],
#         [0.1642],
#         [0.5897]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0274],
#         [0.1843],
#         [0.1622],
#         [0.5953]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0262],
#         [0.1819],
#         [0.1602],
#         [0.6009]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0251],
#         [0.1795],
#         [0.1583],
#         [0.6064]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0240],
#         [0.1770],
#         [0.1563],
#         [0.6119]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0230],
#         [0.1746],
#         [0.1543],
#         [0.6173]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0220],
#         [0.1722],
#         [0.1523],
#         [0.6226]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0211],
#         [0.1698],
#         [0.1504],
#         [0.6279]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
# predict with model : tensor([[0.0202],
#         [0.1674],
#         [0.1484],
#         [0.6332]])
# real value y : tensor([[0.],
#         [0.],
#         [0.],
#         [1.]])
